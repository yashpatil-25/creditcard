# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1081

# %%
df = df.drop_duplicates()

# %%
plt.boxplot(df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x17b11500080>,
#   <matplotlib.lines.Line2D at 0x17b114d05c0>,
#   <matplotlib.lines.Line2D at 0x17b115011f0>,
#   <matplotlib.lines.Line2D at 0x17b115014f0>,
#   <matplotlib.lines.Line2D at 0x17b11502570>,
#   <matplotlib.lines.Line2D at 0x17b11502840>,
#   <matplotlib.lines.Line2D at 0x17b115038f0>,
#   <matplotlib.lines.Line2D at 0x17b11503bc0>,
#   <matplotlib.lines.Line2D at 0x17b1152cd70>,
#   <matplotlib.lines.Line2D at 0x17b1152d070>,
#   <matplotlib.lines.Line2D at 0x17b1152e150>,
#   <matplotlib.lines.Line2D at 0x17b1152e420>,
#   <matplotlib.lines.Line2D at 0x17b1152f4a0>,
#   <matplotlib.lines.Line2D at 0x17b1152f7a0>,
#   <matplotlib.lines.Line2D at 0x17b11578860>,
#   <matplotlib.lines.Line2D at 0x17b11578b60>,
#   <matplotlib.lines.Line2D at 0x17b11579c10>,
#   <matplotlib.lines.Line2D at 0x17b11579eb0>,
#   <matplotlib.lines.Line2D at 0x17b1157af90>,
#   <matplotlib.lines.Line2D at 0x17b1157b230>,
#   <matplotlib.lines.Line2D at 0x17b115ac2c0>,
#   <matplotlib.lines.Line2D at 0x17b115ac560>,
#   <matplotlib.lines.Line2D at 0x17b115ad5b0>,
#   <matplotlib.lines.Line2D at 0x17b115ad880>,
#   <matplotlib.lines.Line2D at 0x17b115ae900>,
#   <matplotlib.lines.Line2D at 0x17b115aebd0>,
#   <matplotlib.lines.Line2D at 0x17b115afbf0>,
#   <matplotlib.lines.Line2D at 0x17b115afe90>,
#   <matplotlib.lines.Line2D at 0x17b115d8dd0>,
#   <matplotlib.lines.Line2D at 0x17b115d90a0>,
#   <matplotlib.lines.Line2D at 0x17b115da090>,
#   <matplotlib.lines.Line2D at 0x17b115da360>,
#   <matplotlib.lines.Line2D at 0x17b115db350>,
#   <matplotlib.lines.Line2D at 0x17b115db5c0>,
#   <matplotlib.lines.Line2D at 0x17b11604740>,
#   <matplotlib.lines.Line2D at 0x17b116049e0>,
#   <matplotlib.lines.Line2D at 0x17b11605a00>,
#   <matplotlib.lines.Line2D at 0x17b11605c40>,
#   <matplotlib.lines.Line2D at 0x17b11606c30>,
#   <matplotlib.lines.Line2D at 0x17b11606e70>,
#   <matplotlib.lines.Line2D at 0x17b11607e60>,
#   <matplotlib.lines.Line2D at 0x17b11630140>,
#   <matplotlib.lines.Line2D at 0x17b11631250>,
#   <matplotlib.lines.Line2D at 0x17b11631520>,
#   <matplotlib.lines.Line2D at 0x17b116325a0>,
#   <matplotlib.lines.Line2D at 0x17b11632810>,
#   <matplotlib.lines.Line2D at 0x17b116337d0>,
#   <matplotlib.lines.Line2D at 0x17b11633a70>,
#   <matplotlib.lines.Line2D at 0x17b11664b90>,
#   <matplotlib.lines.Line2D at 0x17b11664e30>,
#   <matplotlib.lines.Line2D at 0x17b11665d30>,
#   <matplotlib.lines.Line2D at 0x17b11666000>,
#   <matplotlib.lines.Line2D at 0x17b11667050>,
#   <matplotlib.lines.Line2D at 0x17b11667320>,
#   <matplotlib.lines.Line2D at 0x17b11304050>,
#   <matplotlib.lines.Line2D at 0x17b113042f0>,
#   <matplotlib.lines.Line2D at 0x17b11305220>,
#   <matplotlib.lines.Line2D at 0x17b113054c0>,
#   <matplotlib.lines.Line2D at 0x17b11306450>,
#   <matplotlib.lines.Line2D at 0x17b113066f0>,
#   <matplotlib.lines.Line2D at 0x17b11307740>,
#   <matplotlib.lines.Line2D at 0x17b11307a40>],
#  'caps': [<matplotlib.lines.Line2D at 0x17b115004d0>,
#   <matplotlib.lines.Line2D at 0x17b115007a0>,
#   <matplotlib.lines.Line2D at 0x17b11501790>,
#   <matplotlib.lines.Line2D at 0x17b11501a60>,
#   <matplotlib.lines.Line2D at 0x17b11502b10>,
#   <matplotlib.lines.Line2D at 0x17b11502de0>,
#   <matplotlib.lines.Line2D at 0x17b11503ec0>,
#   <matplotlib.lines.Line2D at 0x17b1152c200>,
#   <matplotlib.lines.Line2D at 0x17b1152d340>,
#   <matplotlib.lines.Line2D at 0x17b1152d640>,
#   <matplotlib.lines.Line2D at 0x17b1152e6f0>,
#   <matplotlib.lines.Line2D at 0x17b1152e960>,
#   <matplotlib.lines.Line2D at 0x17b1152faa0>,
#   <matplotlib.lines.Line2D at 0x17b1152fd70>,
#   <matplotlib.lines.Line2D at 0x17b11578e60>,
#   <matplotlib.lines.Line2D at 0x17b11579160>,
#   <matplotlib.lines.Line2D at 0x17b1157a150>,
#   <matplotlib.lines.Line2D at 0x17b1157a450>,
#   <matplotlib.lines.Line2D at 0x17b1157b530>,
#   <matplotlib.lines.Line2D at 0x17b1157b800>,
#   <matplotlib.lines.Line2D at 0x17b115ac830>,
#   <matplotlib.lines.Line2D at 0x17b115acb00>,
#   <matplotlib.lines.Line2D at 0x17b115adac0>,
#   <matplotlib.lines.Line2D at 0x17b115addc0>,
#   <matplotlib.lines.Line2D at 0x17b115aeed0>,
#   <matplotlib.lines.Line2D at 0x17b115af110>,
#   <matplotlib.lines.Line2D at 0x17b115d8170>,
#   <matplotlib.lines.Line2D at 0x17b115d83b0>,
#   <matplotlib.lines.Line2D at 0x17b115d9340>,
#   <matplotlib.lines.Line2D at 0x17b115d9610>,
#   <matplotlib.lines.Line2D at 0x17b115da630>,
#   <matplotlib.lines.Line2D at 0x17b115da8a0>,
#   <matplotlib.lines.Line2D at 0x17b115db890>,
#   <matplotlib.lines.Line2D at 0x17b115dbb60>,
#   <matplotlib.lines.Line2D at 0x17b11604cb0>,
#   <matplotlib.lines.Line2D at 0x17b11604f80>,
#   <matplotlib.lines.Line2D at 0x17b11605f10>,
#   <matplotlib.lines.Line2D at 0x17b116061e0>,
#   <matplotlib.lines.Line2D at 0x17b11607080>,
#   <matplotlib.lines.Line2D at 0x17b11607320>,
#   <matplotlib.lines.Line2D at 0x17b11630410>,
#   <matplotlib.lines.Line2D at 0x17b11630710>,
#   <matplotlib.lines.Line2D at 0x17b116317f0>,
#   <matplotlib.lines.Line2D at 0x17b11631ac0>,
#   <matplotlib.lines.Line2D at 0x17b11632a80>,
#   <matplotlib.lines.Line2D at 0x17b11632d80>,
#   <matplotlib.lines.Line2D at 0x17b11633d10>,
#   <matplotlib.lines.Line2D at 0x17b11664050>,
#   <matplotlib.lines.Line2D at 0x17b11665100>,
#   <matplotlib.lines.Line2D at 0x17b11665340>,
#   <matplotlib.lines.Line2D at 0x17b11666300>,
#   <matplotlib.lines.Line2D at 0x17b116665d0>,
#   <matplotlib.lines.Line2D at 0x17b11667590>,
#   <matplotlib.lines.Line2D at 0x17b11667860>,
#   <matplotlib.lines.Line2D at 0x17b11304560>,
#   <matplotlib.lines.Line2D at 0x17b113047d0>,
#   <matplotlib.lines.Line2D at 0x17b11305700>,
#   <matplotlib.lines.Line2D at 0x17b11305a00>,
#   <matplotlib.lines.Line2D at 0x17b113069c0>,
#   <matplotlib.lines.Line2D at 0x17b11306c30>,
#   <matplotlib.lines.Line2D at 0x17b11307ce0>,
#   <matplotlib.lines.Line2D at 0x17b11307fe0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x17b10c24830>,
#   <matplotlib.lines.Line2D at 0x17b11500ef0>,
#   <matplotlib.lines.Line2D at 0x17b11502270>,
#   <matplotlib.lines.Line2D at 0x17b11503620>,
#   <matplotlib.lines.Line2D at 0x17b1152ca70>,
#   <matplotlib.lines.Line2D at 0x17b1152de80>,
#   <matplotlib.lines.Line2D at 0x17b1152f1a0>,
#   <matplotlib.lines.Line2D at 0x17b11578590>,
#   <matplotlib.lines.Line2D at 0x17b115799a0>,
#   <matplotlib.lines.Line2D at 0x17b1157acc0>,
#   <matplotlib.lines.Line2D at 0x17b1157bfb0>,
#   <matplotlib.lines.Line2D at 0x17b115ad2e0>,
#   <matplotlib.lines.Line2D at 0x17b115ae600>,
#   <matplotlib.lines.Line2D at 0x17b115af950>,
#   <matplotlib.lines.Line2D at 0x17b115d8b60>,
#   <matplotlib.lines.Line2D at 0x17b115d9df0>,
#   <matplotlib.lines.Line2D at 0x17b115db0b0>,
#   <matplotlib.lines.Line2D at 0x17b11604470>,
#   <matplotlib.lines.Line2D at 0x17b11605790>,
#   <matplotlib.lines.Line2D at 0x17b11606990>,
#   <matplotlib.lines.Line2D at 0x17b11607bc0>,
#   <matplotlib.lines.Line2D at 0x17b11630f50>,
#   <matplotlib.lines.Line2D at 0x17b11632300>,
#   <matplotlib.lines.Line2D at 0x17b11633530>,
#   <matplotlib.lines.Line2D at 0x17b116648c0>,
#   <matplotlib.lines.Line2D at 0x17b11665ac0>,
#   <matplotlib.lines.Line2D at 0x17b11666db0>,
#   <matplotlib.lines.Line2D at 0x17b11667d70>,
#   <matplotlib.lines.Line2D at 0x17b11304f50>,
#   <matplotlib.lines.Line2D at 0x17b113061e0>,
#   <matplotlib.lines.Line2D at 0x17b11307470>],
#  'medians': [<matplotlib.lines.Line2D at 0x17b11500a70>,
#   <matplotlib.lines.Line2D at 0x17b11501d00>,
#   <matplotlib.lines.Line2D at 0x17b115030b0>,
#   <matplotlib.lines.Line2D at 0x17b1152c4d0>,
#   <matplotlib.lines.Line2D at 0x17b1152d8e0>,
#   <matplotlib.lines.Line2D at 0x17b1152ec60>,
#   <matplotlib.lines.Line2D at 0x17b115780b0>,
#   <matplotlib.lines.Line2D at 0x17b11579430>,
#   <matplotlib.lines.Line2D at 0x17b1157a750>,
#   <matplotlib.lines.Line2D at 0x17b1157baa0>,
#   <matplotlib.lines.Line2D at 0x17b115acd70>,
#   <matplotlib.lines.Line2D at 0x17b115ae0c0>,
#   <matplotlib.lines.Line2D at 0x17b115af3b0>,
#   <matplotlib.lines.Line2D at 0x17b115d8680>,
#   <matplotlib.lines.Line2D at 0x17b115d98e0>,
#   <matplotlib.lines.Line2D at 0x17b115daba0>,
#   <matplotlib.lines.Line2D at 0x17b115dbe60>,
#   <matplotlib.lines.Line2D at 0x17b11605250>,
#   <matplotlib.lines.Line2D at 0x17b11606480>,
#   <matplotlib.lines.Line2D at 0x17b116075f0>,
#   <matplotlib.lines.Line2D at 0x17b11630980>,
#   <matplotlib.lines.Line2D at 0x17b11631d90>,
#   <matplotlib.lines.Line2D at 0x17b11633050>,
#   <matplotlib.lines.Line2D at 0x17b11664350>,
#   <matplotlib.lines.Line2D at 0x17b116655e0>,
#   <matplotlib.lines.Line2D at 0x17b116668a0>,
#   <matplotlib.lines.Line2D at 0x17b11667b30>,
#   <matplotlib.lines.Line2D at 0x17b11304a40>,
#   <matplotlib.lines.Line2D at 0x17b11305cd0>,
#   <matplotlib.lines.Line2D at 0x17b11306ed0>,
#   <matplotlib.lines.Line2D at 0x17b116ac260>],
#  'fliers': [<matplotlib.lines.Line2D at 0x17b11500d10>,
#   <matplotlib.lines.Line2D at 0x17b11501fd0>,
#   <matplotlib.lines.Line2D at 0x17b11503380>,
#   <matplotlib.lines.Line2D at 0x17b1152c7a0>,
#   <matplotlib.lines.Line2D at 0x17b1152dbe0>,
#   <matplotlib.lines.Line2D at 0x17b1152ef00>,
#   <matplotlib.lines.Line2D at 0x17b11578350>,
#   <matplotlib.lines.Line2D at 0x17b11579730>,
#   <matplotlib.lines.Line2D at 0x17b1157a9f0>,
#   <matplotlib.lines.Line2D at 0x17b1157bda0>,
#   <matplotlib.lines.Line2D at 0x17b115ad010>,
#   <matplotlib.lines.Line2D at 0x17b115ae360>,
#   <matplotlib.lines.Line2D at 0x17b115af6b0>,
#   <matplotlib.lines.Line2D at 0x17b115d88f0>,
#   <matplotlib.lines.Line2D at 0x17b115d9bb0>,
#   <matplotlib.lines.Line2D at 0x17b115dae40>,
#   <matplotlib.lines.Line2D at 0x17b116041a0>,
#   <matplotlib.lines.Line2D at 0x17b116054f0>,
#   <matplotlib.lines.Line2D at 0x17b11606750>,
#   <matplotlib.lines.Line2D at 0x17b116078f0>,
#   <matplotlib.lines.Line2D at 0x17b11630c80>,
#   <matplotlib.lines.Line2D at 0x17b11632030>,
#   <matplotlib.lines.Line2D at 0x17b11633320>,
#   <matplotlib.lines.Line2D at 0x17b116645f0>,
#   <matplotlib.lines.Line2D at 0x17b116657f0>,
#   <matplotlib.lines.Line2D at 0x17b11666b10>,
#   <matplotlib.lines.Line2D at 0x17b104532f0>,
#   <matplotlib.lines.Line2D at 0x17b11304d40>,
#   <matplotlib.lines.Line2D at 0x17b11305fa0>,
#   <matplotlib.lines.Line2D at 0x17b113071d0>,
#   <matplotlib.lines.Line2D at 0x17b116ac4a0>],
#  'means': []}

# %%
X = df.drop('Class', axis=1)
y = df['Class']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-0.77717232, -0.69712346, -0.65378113, ..., -0.45050471,
#         -0.28613705,  0.90921189],
#        [ 1.41573069, -0.03297944,  0.35495872, ..., -0.31091542,
#         -0.60165535, -0.21863125],
#        [-1.12714577, -0.18810283,  0.43538871, ...,  0.0731303 ,
#          0.17466732, -0.27144194],
#        ...,
#        [-0.31164996,  0.64414423, -0.02827519, ...,  0.11072017,
#          0.07429506, -0.33281011],
#        [-0.13156797,  1.01553945, -0.07978255, ..., -0.1854883 ,
#         -0.17215102, -0.1942266 ],
#        [-0.38376276, -0.24096194,  0.49800783, ..., -0.33464112,
#         -0.14752314, -0.35063818]])

# %%
X_test
# Out:
# array([[-0.5387895 ,  0.53896015, -0.46199837, ...,  0.25187121,
#          0.12029052, -0.12711384],
#        [-0.29510086, -2.46852622,  2.64018286, ...,  1.08277702,
#         -1.33294066, -0.31173338],
#        [-1.12859855, -0.79769251, -0.15662003, ..., -1.2701668 ,
#         -0.76122569, -0.16807877],
#        ...,
#        [ 0.6708949 ,  1.01232783, -0.18483459, ..., -0.21554244,
#         -0.18268072, -0.21997826],
#        [-0.96683426, -1.46398734, -1.41475957, ...,  0.64493323,
#         -1.09651024,  0.01289592],
#        [ 1.39457058, -0.03594487,  0.47606942, ...,  1.45557384,
#          0.96007385, -0.31300115]])

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier


knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.9994889507630493
